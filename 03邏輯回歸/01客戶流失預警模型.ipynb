# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_excel("/content/股票客户流失.xlsx")
df.head()
# Out:
#     账户资金（元）  最后一次交易距今时间（天）  上月交易佣金（元）  累计交易佣金（元）  本券商使用时长（年）  是否流失
# 0   22686.5            297     149.25    2029.85           0     0
# 1  190055.0             42     284.75    3889.50           2     0
# 2   29733.5            233     269.25    2108.15           0     1
# 3  185667.5             44     211.50    3840.75           3     0
# 4   33648.5            213     353.50    2151.65           0     1

# %%
# 劃分特征變量和目標變量
X = df.drop(columns='是否流失')
y = df['是否流失']

# %%
# 劃分訓練集和測試集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=666)

# %%
# 模型訓練
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.7778566359119943

# %%
# 模型使用1 - 預測數據結果
y_pred = model.predict(X_test)
y_pred
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
# 模型使用2 - 預測股票客戶的流失概率
y_pred_proba = model.predict_proba(X_test)
y_pred_proba[:5]
# Out:
# array([[0.89720249, 0.10279751],
#        [0.48321256, 0.51678744],
#        [0.5807161 , 0.4192839 ],
#        [0.8726224 , 0.1273776 ],
#        [0.32802984, 0.67197016]])

# %%
# 只查看流失的概率
print("股票客戶流失概率", y_pred_proba[:,1])
# Out:
# 股票客戶流失概率 [0.10279751 0.51678744 0.4192839  ... 0.20036486 0.09392911 0.05899742]
