# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_excel("/content/客户价值数据表.xlsx")
df.head()
# Out:
#    客户价值  历史贷款金额  贷款次数  学历    月收入  性别
# 0  1150    6488     2   2   9567   1
# 1  1157    5194     4   2  10767   0
# 2  1163    7066     3   2   9317   0
# 3   983    3550     3   2  10517   0
# 4  1205    7847     3   3  11267   1

# %%
# 划分特征变量和目标变量
X = df[["历史贷款金额","贷款次数","学历","月收入","性别"]]
y = df[['客户价值']]

# %%
# 划分数据集
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=666)

# %%
# 模型训练
regr = LinearRegression()
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 打印线性回归方程系数
print("系数：",regr.coef_)
print("截距：",regr.intercept_)
# Out:
# 系数： [[ 5.01606076e-02  1.06662925e+02  9.66433358e+01  7.18473509e-02
#   -1.19784899e+00]]
# 截距： [-318.95469308]

# %%
#模型评估
print("内置的r2方法：",regr.score(X_test, y_test))
print("r2_score函数得到的r2值", r2_score(y_test,regr.predict(X_test)))
# Out:
# 内置的r2方法： 0.582015509154677
# r2_score函数得到的r2值 0.582015509154677
