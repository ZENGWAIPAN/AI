# %%
import pandas as pd
import statsmodels.stats.contingency_tables as tbl
import numpy as np

# %%
table = tbl.SquareTable(np.array([[56,35],[21,28]]))
print(table.summary())
print(table.symmetry())
# Out:
#             Statistic P-value DF
# --------------------------------
# Symmetry        3.500   0.061  1
# Homogeneity     3.500   0.061  1
# --------------------------------
# df          1.0
# pvalue      0.0613688291394023
# statistic   3.5

# %%
table = tbl.mcnemar(pd.DataFrame([[56,35],[21,28]]))
table.pvalue
# Out:
# 0.08142681460950618
